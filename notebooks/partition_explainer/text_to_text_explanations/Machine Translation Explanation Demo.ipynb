# %% [markdown]
# # Text to Text Explanation: Machine Translation Example

# %% [markdown]
# This notebook demonstrates use of generating model explanations for a text to text scenario on a pretrained transformer model for machine translation. In this demo, we showcase explanations on 3 different models trained provided by hugging face which inclues translation from English to Spanish (https://huggingface.co/Helsinki-NLP/opus-mt-en-es), English to French (https://huggingface.co/Helsinki-NLP/opus-mt-en-fr) and English to German (https://huggingface.co/Helsinki-NLP/opus-mt-en-gem).

# %%
import numpy as np
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import shap
import torch

# %% [markdown]
# ## English to Spanish

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-es")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-es").cuda()

# %% [markdown]
# ### Define data to translate

# %%
s="In this picture, there are four persons: my father, my mother, my brother and my sister."

# %% [markdown]
# ### Create an explainer object

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %% [markdown]
# ### Compute shap values

# %%
shap_values = explainer([s])

# %% [markdown]
# ### Visualize shap explanations

# %%
shap.plots.text(shap_values[0])
# Out:
# invalid value encountered in double_scalars
#     <script>
#         function selectVizType_ueuwwovcxjhtyywgakqf(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("ueuwwovcxjhtyywgakqf_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('ueuwwovcxjhtyywgakqf_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('ueuwwovcxjhtyywgakqf_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="ueuwwovcxjhtyywgakqf_viz_container">
#       <div id="ueuwwovcxjhtyywgakqf_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="ueuwwovcxjhtyywgakqf_viz_type" onchange="selectVizType_ueuwwovcxjhtyywgakqf(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="ueuwwovcxjhtyywgakqf_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "ueuwwovcxjhtyywgakqf_saliency_plot_container" class="ueuwwovcxjhtyywgakqf_viz_container" style="display:none">
#
#         <div id="fdvtnjsvhuchthqhukqi_saliency_plot" class="fdvtnjsvhuchthqhukqi_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
, 0.09348385818974048)">-0.057</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.057</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.057</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.057</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.057</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.057</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0. ...

# %% [markdown]
# ## English to French

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr",use_fast=True)
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %%
shap_values = explainer([s])

# %%
shap.plots.text(shap_values[0])
# Out:
# invalid value encountered in double_scalars
#     <script>
#         function selectVizType_ygvwwpwwyuefrlveublj(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("ygvwwpwwyuefrlveublj_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('ygvwwpwwyuefrlveublj_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('ygvwwpwwyuefrlveublj_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="ygvwwpwwyuefrlveublj_viz_container">
#       <div id="ygvwwpwwyuefrlveublj_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="ygvwwpwwyuefrlveublj_viz_type" onchange="selectVizType_ygvwwpwwyuefrlveublj(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="ygvwwpwwyuefrlveublj_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "ygvwwpwwyuefrlveublj_saliency_plot_container" class="ygvwwpwwyuefrlveublj_viz_container" style="display:none">
#
#         <div id="ljumzxbgpfyumjxmwggh_saliency_plot" class="ljumzxbgpfyumjxmwggh_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>In </th><th>this </th><th>picture </th><th>, </th><th>there </th><th>are </th><th>four </th><th>persons </th><th>: </th><th>my </th><th>father </th><th>, </th><th>my </th><th>mother </th><th>, </th><th>my </th><th>brother </th><th>and </th><th>my </th><th>sister </th><th>. </th><th> </th></tr><tr><th>Sur</th><th style="background:rgba(255.0, 13.0, 87.0, 0.9527035056446822)">2.849</th><th style="background:rgba(255.0, 13.0, 87.0, 0.9527035056446822)">2.849</th><th style="background:
# %% [markdown]
# ## English to German

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-gem",use_fast=True)
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-gem")

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %%
shap_values = explainer([s])

# %%
shap.plots.text(shap_values[0])
# Out:
# invalid value encountered in double_scalars
#     <script>
#         function selectVizType_jqbcmvmvycoacdnvaaer(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("jqbcmvmvycoacdnvaaer_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('jqbcmvmvycoacdnvaaer_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('jqbcmvmvycoacdnvaaer_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="jqbcmvmvycoacdnvaaer_viz_container">
#       <div id="jqbcmvmvycoacdnvaaer_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="jqbcmvmvycoacdnvaaer_viz_type" onchange="selectVizType_jqbcmvmvycoacdnvaaer(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="jqbcmvmvycoacdnvaaer_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "jqbcmvmvycoacdnvaaer_saliency_plot_container" class="jqbcmvmvycoacdnvaaer_viz_container" style="display:none">
#
#         <div id="clcvmvhsgczckqrivhji_saliency_plot" class="clcvmvhsgczckqrivhji_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>In </th><th>this </th><th>picture </th><th>, </th><th>there </th><th>are </th><th>four </th><th>persons </th><th>: </th><th>my </th><th>father </th><th>, </th><th>my </th><th>mother </th><th>, </th><th>my </th><th>brother </th><th>and </th><th>my </th><th>sister </th><th>. </th><th> </th></tr><tr><th>I</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">3.798</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">3.798</th><th style="background:rgba(255.0, 13.0, 87.0, 0.8186967716379481)">3.103</th><th style="background:rgba(30.0, 136.0, 229.0, 0.08560110913052085)">-0.33</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.445</th><th style="background:rgba(