# %% [markdown]
# # Text to Text Explanation: Open Ended Text Generation Using GPT2

# %% [markdown]
# This notebook demonstrates how to get explanations for the output of gpt2 used for open ended text generation. In this demo, we use the pretrained gpt2 model provided by hugging face (https://huggingface.co/gpt2) to explain the generated text by gpt2. We further showcase how to get explanations for custom output generated text and plot global input token importances for any output generated token.

# %%
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM
import shap
import torch

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model =  AutoModelForCausalLM.from_pretrained("gpt2").cuda()

# %% [markdown]
# Below, we set certain model configurations. We need to define if the model is a decoder or encoder-decoder.
# This can be set through the 'is_decoder' or 'is_encoder_decoder' param in model's config file.
# We can also set custom model generation parameters which will be used during the output text generation decoding process.

# %%
# set model decoder to true and generation params
model.config.is_decoder=True
model.config.text_generation_params = {
    "do_sample": True,
    "max_length": 50,
    "temperature": 0.7,
    "top_k": 0
  }

# %% [markdown]
# ### Define initial text

# %%
s = ['I enjoy walking with my cute dog']

# %% [markdown]
# ### Create an explainer object

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %% [markdown]
# ### Compute shap values

# %%
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence

# %% [markdown]
# ### Visualize shap explanations

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_ooprehyoixfwaxklpdts(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("ooprehyoixfwaxklpdts_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('ooprehyoixfwaxklpdts_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('ooprehyoixfwaxklpdts_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="ooprehyoixfwaxklpdts_viz_container">
#       <div id="ooprehyoixfwaxklpdts_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="ooprehyoixfwaxklpdts_viz_type" onchange="selectVizType_ooprehyoixfwaxklpdts(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="ooprehyoixfwaxklpdts_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "ooprehyoixfwaxklpdts_saliency_plot_container" class="ooprehyoixfwaxklpdts_viz_container" style="display:none">
#
#         <div id="aiarhiefhemqdvuwpoek_saliency_plot" class="aiarhiefhemqdvuwpoek_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
r><th>family</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.476</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.81</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.258</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.094</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.44</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.377</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06195286195286207)">0.229</th></tr><tr><th>and</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.311</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06983561101208147)">-0.259</th><th style="background:rgba(30.0, 136.0, 229.0, 0.006773618538324436)">-0.041</th><th style="background:rgba( ...

# %% [markdown]
# ### Another example...

# %%
s=['Scientists confirmed the worst possible outcome: the massive asteroid will collide with Earth']

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %%
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_uvmwjwsdqfvpywnvhkbi(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("uvmwjwsdqfvpywnvhkbi_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('uvmwjwsdqfvpywnvhkbi_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('uvmwjwsdqfvpywnvhkbi_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="uvmwjwsdqfvpywnvhkbi_viz_container">
#       <div id="uvmwjwsdqfvpywnvhkbi_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="uvmwjwsdqfvpywnvhkbi_viz_type" onchange="selectVizType_uvmwjwsdqfvpywnvhkbi(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="uvmwjwsdqfvpywnvhkbi_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "uvmwjwsdqfvpywnvhkbi_saliency_plot_container" class="uvmwjwsdqfvpywnvhkbi_viz_container" style="display:none">
#
#         <div id="vbfckrvihiacwmopvspo_saliency_plot" class="vbfckrvihiacwmopvspo_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
.15654585066349747)">0.642</th></tr><tr><th>and</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.316</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.393</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.373</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.054</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.245</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.161</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.192</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03042186571598325)">-0.16</th><th style="background:rgba(255.0, 13.0, 87.0, 0.093483858189740 ...

# %% [markdown]
# ##  Custom text generation and debugging biased outputs

# %% [markdown]
# Below we demonstrate the process of how to explain the liklihood of generating a particular output sentence given an input sentence using the model. <br><br>
# For example, we ask a question:<br>
# Which country's inhabitant (target) in the sentence "I know many people who are [<b>target</b>]." would have a high liklilhood of generating the token "vodka" in the output sentence "They love their <b>vodka</b>!" ?
# <br><br>
# For this, we first define input-output sentence pairs

# %%
biased_sentence_pairs = {
    "I know many people who are Russian." : "They love their vodka!",
    "I know many people who are Greek." : "They love their vodka!",
    "I know many people who are Australian." : "They love their vodka!",
    "I know many people who are American." : "They love their vodka!",
    "I know many people who are Italian." : "They love their vodka!",
    "I know many people who are Spanish." : "They love their vodka!",
    "I know many people who are German." : "They love their vodka!",
    "I know many people who are Indian." : "They love their vodka!"
}

# %% [markdown]
# Next we define a custom text generation function which returns the target sentence ids of the output sentence of choice to be generated by the model.

# %%
def generate_biased_output(x):
    # we get the target sentence by a dictionary lookup from the previously defined sentence pairs
    target_sentence = biased_sentence_pairs[x]
    target_sentence_ids = torch.tensor([tokenizer.encode(target_sentence)])
    return target_sentence_ids

# %% [markdown]
# We wrap the model with a Teacher Forcing Logits scoring class and create a Text masker

# %%
wrapped_model = shap.models.TeacherForcingLogits(model, tokenizer, generation_function_for_target_sentence_ids=generate_biased_output)
masker = shap.maskers.Text(tokenizer, mask_token = "...", collapse_mask_token=True)

# %% [markdown]
# Create an explainer...

# %%
explainer = shap.Explainer(wrapped_model,masker)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %% [markdown]
# Define the data to run the explainer on...

# %%
s = list(biased_sentence_pairs.keys())

# %% [markdown]
# Generate SHAP explanation values!

# %%
shap_values = explainer(s)
# Out:
# Partition explainer: 9it [00:10,  1.13s/it]

# %% [markdown]
# Now that we have generated the SHAP values, we can have a look at the contribution of tokens in the input driving the token "vodka" in the output sentence using the text plot. <br><br>
# <b>Note:</b> The red color indicates a positive contribution while the blue color indicates negative contribution and the intensity of the color shows its strength in the respective direction.

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_aoepzqkduxtnpdhdtosd(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("aoepzqkduxtnpdhdtosd_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('aoepzqkduxtnpdhdtosd_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('aoepzqkduxtnpdhdtosd_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="aoepzqkduxtnpdhdtosd_viz_container">
#       <div id="aoepzqkduxtnpdhdtosd_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="aoepzqkduxtnpdhdtosd_viz_type" onchange="selectVizType_aoepzqkduxtnpdhdtosd(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="aoepzqkduxtnpdhdtosd_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "aoepzqkduxtnpdhdtosd_saliency_plot_container" class="aoepzqkduxtnpdhdtosd_viz_container" style="display:none">
#
#         <div id="ujsodtonujtdfwofrydl_saliency_plot" class="ujsodtonujtdfwofrydl_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Russian</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1328976034858387)">-0.377</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.158</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.157</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.125</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.164</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.341</th><th style="background:rgba(30.0, 136.0, 229.0, 0.25113883937413345)">-0.695</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.222</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.126</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.448</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.248</th><th style="background:rgba(255.0, 13.0, 87.0, 0.16442859972271742)">0.45</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.057</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.023</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.015</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.143</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.069</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.088</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.297</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.144</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.159</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.25</th><th style="background:rgba(30.0, 136.0, 229.0, 0.006773618538324436)">-0.022</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.07</th></tr><tr><th>vodka</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.036</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.013</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.132</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.021</th><th style="background:rgba(30.0, 136.0, 229.0, 0.014656367597544028)">-0.044</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.151</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">2.743</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.076</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1565458506634977)">-0.449</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.182</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.126</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.309</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.142</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03042186571598325)">-0.096</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.282</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.147</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "aoepzqkduxtnpdhdtosd_heatmap_container" class="aoepzqkduxtnpdhdtosd_viz_container">
#
#         <div id="bjujjuhxssfxadnlztlo_heatmap" class="bjujjuhxssfxadnlztlo_viz_content">
#           <div id="bjujjuhxssfxadnlztlo_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="bjujjuhxssfxadnlztlo_alignment" onchange="selectAlignment_bjujjuhxssfxadnlztlo(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="bjujjuhxssfxadnlztlo_heatmap_content" style="display:flex;">
#             <div id="bjujjuhxssfxadnlztlo_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="bjujjuhxssfxadnlztlo_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="bjujjuhxssfxadnlztlo_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="bjujjuhxssfxadnlztlo_input_node_14_container" style="display:inline;text-align:center"><div id="bjujjuhxssfxadnlztlo_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="bjujjuhxssfxadnlztlo_input_node_14_content" style="display:inline;"><div id="bjujjuhxssfxadnlztlo_input_node_12_container" style="display:inline;text-align:center"><div id="bjujjuhxssfxadnlztlo_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="bjujjuhxssfxadnlztlo_input_node_12_content" style="display:inline;"><div id="bjujjuhxssfxadnlztlo_input_node_8_container" style="display:inline;text-align:center"><div id="bjujjuhxssfxadnlztlo_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="bjujjuhxssfxadnlztlo_input_node_8_content" style="display:inline;"><div id="bjujjuhxssfxadnlztlo_input_node_0_container" style="display:inline;text-align:center"><div id="bjujjuhxssfxadnlztlo_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="bjujjuhxssfxadnlztlo_input_node_0_content"s
# <br/><b>1st instance:</b><br/>
#     <script>
#         function selectVizType_iaebazlisutjcapnbdhg(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("iaebazlisutjcapnbdhg_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('iaebazlisutjcapnbdhg_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('iaebazlisutjcapnbdhg_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="iaebazlisutjcapnbdhg_viz_container">
#       <div id="iaebazlisutjcapnbdhg_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="iaebazlisutjcapnbdhg_viz_type" onchange="selectVizType_iaebazlisutjcapnbdhg(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="iaebazlisutjcapnbdhg_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "iaebazlisutjcapnbdhg_saliency_plot_container" class="iaebazlisutjcapnbdhg_viz_container" style="display:none">
#
#         <div id="zlnkxopkrmprglmkkcbb_saliency_plot" class="zlnkxopkrmprglmkkcbb_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#         </div>
#
#           </div>
#
#           <div id = "iaebazlisutjcapnbdhg_heatmap_container" class="iaebazlisutjcapnbdhg_viz_container">
#
#         <div id="elyfmblfdomrusercpyn_heatmap" class="elyfmblfdomrusercpyn_viz_content">
#           <div id="elyfmblfdomrusercpyn_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="elyfmblfdomrusercpyn_alignment" onchange="selectAlignment_elyfmblfdomrusercpyn(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="elyfmblfdomrusercpyn_heatmap_content" style="display:flex;">
#             <div id="elyfmblfdomrusercpyn_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="elyfmblfdomrusercpyn_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="elyfmblfdomrusercpyn_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="elyfmblfdomrusercpyn_input_node_14_container" style="display:inline;text-align:center"><div id="elyfmblfdomrusercpyn_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="elyfmblfdomrusercpyn_input_node_14_content" style="display:inline;"><div id="elyfmblfdomrusercpyn_input_node_12_container" style="display:inline;text-align:center"><div id="elyfmblfdomrusercpyn_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="elyfmblfdomrusercpyn_input_node_12_content" style="display:inline;"><div id="elyfmblfdomrusercpyn_input_node_8_container" style="display:inline;text-align:center"><div id="elyfmblfdomrusercpyn_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="elyfmblfdomrusercpyn_input_node_8_content" style="display:inline;"><div id="elyfmblfdomrusercpyn_input_node_0_container" style="display:inline;text-align:center"><div id="elyfmblfdomrusercpyn_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="elyfmblfdomrusercpyn_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; p
# <br/><b>2nd instance:</b><br/>
#     <script>
#         function selectVizType_riukiodvoywoyrrdnazv(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("riukiodvoywoyrrdnazv_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('riukiodvoywoyrrdnazv_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('riukiodvoywoyrrdnazv_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="riukiodvoywoyrrdnazv_viz_container">
#       <div id="riukiodvoywoyrrdnazv_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="riukiodvoywoyrrdnazv_viz_type" onchange="selectVizType_riukiodvoywoyrrdnazv(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="riukiodvoywoyrrdnazv_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "riukiodvoywoyrrdnazv_saliency_plot_container" class="riukiodvoywoyrrdnazv_viz_container" style="display:none">
#
#         <div id="nyipxdnsbjdcpliohsdd_saliency_plot" class="nyipxdnsbjdcpliohsdd_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Australian</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5585660526836997)">-0.41</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21172509407803525)">-0.158</th><th style="background:rgba(30.0, 136.0, 229.0, 0.23537334125569417)">-0.176</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.144</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.114</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3299663299663301)">0.247</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-0.737</th><th style="background:rgba(255.0, 13.0, 87.0, 0.7477520301049713)">0.548</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.148</th><th style="background:rgba(255.0, 13.0, 87.0, 0.621628045157457)">0.457</th><th style="background:rgba(255.0, 13.0, 87.0, 0.33784907902554967)">0.248</th><th style="background:rgba(255.0, 13.0, 87.0, 0.6137452960982372)">0.453</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.057</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.004</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5979797979797981)">0.44</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1565458506634977)">-0.118</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.031</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.115</th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.32</th><th style="background:rgba(255.0, 13.0, 87.0, 0.23537334125569415)">0.177</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.168</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4009110714993067)">0.296</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.091</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.036</th></tr><tr><th>vodka</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.14</th><th style="background:rgba(30.0, 136.0, 229.0, 0.12501485442661905)">-0.093</th><th style="background:rgba(30.0, 136.0, 229.0, 0.36149732620320846)">-0.265</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5033868092691621)">-0.371</th><th style="background:rgba(30.0, 136.0, 229.0, 0.12501485442661905)">-0.092</th><th style="background:rgba(30.0, 136.0, 229.0, 0.865993265993266)">-0.635</th><th style="background:rgba(30.0, 136.0, 229.0, 0.40091107149930677)">-0.297</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.003</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.621628045157457)">-0.455</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.201</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.14</th><th style="background:rgba(30.0, 136.0, 229.0, 0.42455931867696567)">-0.315</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.141</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1959595959595959)">-0.149</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29055258467023165)">0.217</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.172</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "riukiodvoywoyrrdnazv_heatmap_container" class="riukiodvoywoyrrdnazv_viz_container">
#
#         <div id="wcfcokqlzkybdscpqebb_heatmap" class="wcfcokqlzkybdscpqebb_viz_content">
#           <div id="wcfcokqlzkybdscpqebb_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="wcfcokqlzkybdscpqebb_alignment" onchange="selectAlignment_wcfcokqlzkybdscpqebb(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="wcfcokqlzkybdscpqebb_heatmap_content" style="display:flex;">
#             <div id="wcfcokqlzkybdscpqebb_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="wcfcokqlzkybdscpqebb_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="wcfcokqlzkybdscpqebb_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="wcfcokqlzkybdscpqebb_input_node_14_container" style="display:inline;text-align:center"><div id="wcfcokqlzkybdscpqebb_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wcfcokqlzkybdscpqebb_input_node_14_content" style="display:inline;"><div id="wcfcokqlzkybdscpqebb_input_node_12_container" style="display:inline;text-align:center"><div id="wcfcokqlzkybdscpqebb_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wcfcokqlzkybdscpqebb_input_node_12_content" style="display:inline;"><div id="wcfcokqlzkybdscpqebb_input_node_8_container" style="display:inline;text-align:center"><div id="wcfcokqlzkybdscpqebb_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wcfcokqlzkybdscpqebb_input_node_8_content" style="display:inline;"><div id="wcfcokqlzkybdscpqebb_input_node_0_container" style="display:inline;text-align:center"><div id="wcfcokqlzkybdscpqebb_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wcfcokqlzkybdscpqebb_input_node_0_content"style='display: inline; background:transparent
# <br/><b>3rd instance:</b><br/>
#     <script>
#         function selectVizType_scrplntpzzarvaufpozl(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("scrplntpzzarvaufpozl_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('scrplntpzzarvaufpozl_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('scrplntpzzarvaufpozl_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="scrplntpzzarvaufpozl_viz_container">
#       <div id="scrplntpzzarvaufpozl_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="scrplntpzzarvaufpozl_viz_type" onchange="selectVizType_scrplntpzzarvaufpozl(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="scrplntpzzarvaufpozl_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "scrplntpzzarvaufpozl_saliency_plot_container" class="scrplntpzzarvaufpozl_viz_container" style="display:none">
#
#         <div id="rcwsqpwvbxnjyxigphcy_saliency_plot" class="rcwsqpwvbxnjyxigphcy_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>American</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5191523073876015)">-0.439</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21960784313725487)">-0.185</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.162</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.099</th><th style="background:rgba(255.0, 13.0, 87.0, 0.306318082788671)">0.262</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-0.84</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.237</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.13</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5349178055060405)">0.451</th><th style="background:rgba(255.0, 13.0, 87.0, 0.20384234501881549)">0.174</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4718558130322837)">0.398</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.
#               <select name="alignment" id="huwnkteethcxlekwgswb_alignment" onchange="selectAlignment_huwnkteethcxlekwgswb(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="huwnkteethcxlekwgswb_heatmap_content" style="display:flex;">
#             <div id="huwnkteethcxlekwgswb_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="huwnkteethcxlekwgswb_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="huwnkteethcxlekwgswb_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="huwnkteethcxlekwgswb_input_node_14_container" style="display:inline;text-align:center"><div id="huwnkteethcxlekwgswb_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="huwnkteethcxlekwgswb_input_node_14_content" style="display:inline;"><div id="huwnkteethcxlekwgswb_input_node_12_container" style="display:inline;text-align:center"><div id="huwnkteethcxlekwgswb_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="huwnkteethcxlekwgswb_input_node_12_content" style="display:inline;"><div id="huwnkteethcxlekwgswb_input_node_8_container" style="display:inline;text-align:center"><div id="huwnkteethcxlekwgswb_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="huwnkteethcxlekwgswb_input_node_8_content" style="display:inline;"><div id="huwnkteethcxlekwgswb_input_node_0_container" style="display:inline;text-align:center"><div id="huwnkteethcxlekwgswb_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="huwnkteethcxlekwgswb_input_node_0_content"style='display: inline; background:transparent; border-radius: 3p
# <br/><b>4th instance:</b><br/>
#     <script>
#         function selectVizType_xuaocjsewcdfiwcleifq(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("xuaocjsewcdfiwcleifq_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('xuaocjsewcdfiwcleifq_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('xuaocjsewcdfiwcleifq_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="xuaocjsewcdfiwcleifq_viz_container">
#       <div id="xuaocjsewcdfiwcleifq_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="xuaocjsewcdfiwcleifq_viz_type" onchange="selectVizType_xuaocjsewcdfiwcleifq(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="xuaocjsewcdfiwcleifq_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "xuaocjsewcdfiwcleifq_saliency_plot_container" class="xuaocjsewcdfiwcleifq_viz_container" style="display:none">
#
background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.077</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.47973856209150334)">-0.467</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1723113487819369)">-0.172</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.11</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.266</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.139</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.079</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5270350564468211)">0.508</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.193</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "xuaocjsewcdfiwcleifq_heatmap_container" class="xuaocjsewcdfiwcleifq_viz_container">
#
#         <div id="lbaajjbythvhzhqguevk_heatmap" class="lbaajjbythvhzhqguevk_viz_content">
#           <div id="lbaajjbythvhzhqguevk_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="lbaajjbythvhzhqguevk_alignment" onchange="selectAlignment_lbaajjbythvhzhqguevk(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="lbaajjbythvhzhqguevk_heatmap_content" style="display:flex;">
#             <div id="lbaajjbythvhzhqguevk_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="lbaajjbythvhzhqguevk_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="lbaajjbythvhzhqguevk_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="lbaajjbythvhzhqguevk_input_node_14_container" style="display:inline;text-align:center"><div id="lbaajjbythvhzhqguevk_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="lbaajjbythvhzhqguevk_input_node_14_content" style="display:inline;"><div id="lbaajjbythvhzhqguevk_input_node_12_container" style="display:inline;text-align:center"><div id="lbaajjbythvhzhqguevk_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="lbaajjbythvhzhqguevk_input_node_12_content" style="display:inline;"><div id="lbaajjbythvhzhqguevk_input_node_8_container" style="display:inline;text-align:center"><div id="lbaajjbythvhzhqguevk_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="lbaajjbythvhzhqguevk_input_node_8_content" style="display:inline;"><div id="lbaajjbythvhzhqguevk_input_node_0_container" style="display:inline;text-align:center"><div id="lbaajjbythvhzhqguevk_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="lbaajjbythvhzhqguevk_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: def
# <br/><b>5th instance:</b><br/>
#     <script>
#         function selectVizType_dmlpulxiclrmjocwlksd(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("dmlpulxiclrmjocwlksd_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('dmlpulxiclrmjocwlksd_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('dmlpulxiclrmjocwlksd_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="dmlpulxiclrmjocwlksd_viz_container">
#       <div id="dmlpulxiclrmjocwlksd_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="dmlpulxiclrmjocwlksd_viz_type" onchange="selectVizType_dmlpulxiclrmjocwlksd(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="dmlpulxiclrmjocwlksd_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "dmlpulxiclrmjocwlksd_saliency_plot_container" class="dmlpulxiclrmjocwlksd_viz_container" style="display:none">
#
#         <div id="gqwpokzwgdrhwplognlu_saliency_plot" class="gqwpokzwgdrhwplognlu_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Spanish</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3220835809071103)">-0.399</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.15</th><th style="background:rgba(30.0, 136.0, 229.0, 0.18019409784115656)">-0.225</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.106</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.284</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4245593186769657)">0.519</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-1.223</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2117250940780353)">0.261</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.149</th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.526</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.225</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3457318280847692)">0.428</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.021</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.048</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3457318280847692)">0.428</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.178</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.06</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.101</th><th style="background:rgba(255.0, 13.0, 87.0, 0.24325609031491383)">0.297</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.157</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.156</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2590215884333532)">0.324</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.011</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.064</th></tr><tr><th>vodka</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03042186571598325)">-0.048</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.099</th><th style="background:rgba(30.0, 136.0, 229.0, 0.2038423450188156)">-0.258</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1328976034858387)">-0.167</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.086</th><th style="background:rgba(30.0, 136.0, 229.0, 0.29055258467023176)">-0.363</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.067</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.003</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.39302832244008723)">-0.482</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.176</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.1</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21960784313725487)">-0.276</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.148</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.064</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2590215884333532)">0.319</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14078035254505847)">0.176</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "dmlpulxiclrmjocwlksd_heatmap_container" class="dmlpulxiclrmjocwlksd_viz_container">
#
#         <div id="blvjvmyrlccrhojkaank_heatmap" class="blvjvmyrlccrhojkaank_viz_content">
#           <div id="blvjvmyrlccrhojkaank_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="blvjvmyrlccrhojkaank_alignment" onchange="selectAlignment_blvjvmyrlccrhojkaank(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="blvjvmyrlccrhojkaank_heatmap_content" style="display:flex;">
#             <div id="blvjvmyrlccrhojkaank_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="blvjvmyrlccrhojkaank_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="blvjvmyrlccrhojkaank_input_content" style="margin:5px;font-family:sans-serif;">
# ...
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("ctgbvylmsaczofwzalsi_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('ctgbvylmsaczofwzalsi_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('ctgbvylmsaczofwzalsi_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="ctgbvylmsaczofwzalsi_viz_container">
#       <div id="ctgbvylmsaczofwzalsi_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="ctgbvylmsaczofwzalsi_viz_type" onchange="selectVizType_ctgbvylmsaczofwzalsi(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="ctgbvylmsaczofwzalsi_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "ctgbvylmsaczofwzalsi_saliency_plot_container" class="ctgbvylmsaczofwzalsi_viz_container" style="display:none">
#
#         <div id="xbpuvlzymvrvbklybequ_saliency_plot" class="xbpuvlzymvrvbklybequ_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>German</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.36938007526242816)">-0.38</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.125</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.282</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.138</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1880768469003763)">0.192</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4087938205585263)">0.417</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-1.018</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29843533372945136)">0.307</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.135</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4718558130322837)">0.482</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.231</th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.44</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.051</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.016</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.187</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1723113487819369)">-0.183</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.059</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.133</th><th style="background:rgba(255.0, 13.0, 87.0, 0.306318082788671)">0.317</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.205</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.185</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.292</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.231</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.062</th></tr><tr><th>vodka</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06983561101208147)">-0.079</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.071</th><th style="background:rgba(30.0, 136.0, 229.0, 0.25902158843335304)">-0.269</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1723113487819369)">-0.182</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.048</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3772628243216478)">-0.388</th><th style="background:rgba(255.0, 13.0, 87.0, 0.8108140225787285)">0.821</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.031</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.4482075658546247)">-0.461</th><th style="background:rgba(30.0, 136.0, 229.0, 0.16442859972271748)">-0.171</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.117</th><th style="background:rgba(30.0, 136.0, 229.0, 0.282669835611012)">-0.293</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14866310160427798)">-0.154</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.084</th><th style="background:rgba(255.0, 13.0, 87.0, 0.41667656961774624)">0.427</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.165</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "ctgbvylmsaczofwzalsi_heatmap_container" class="ctgbvylmsaczofwzalsi_viz_container">
#
#         <div id="ownzbsakgskpznvriwbo_heatmap" class="ownzbsakgskpznvriwbo_viz_content">
#           <div id="ownzbsakgskpznvriwbo_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="ownzbsakgskpznvriwbo_alignment" onchange="selectAlignment_ownzbsakgskpznvriwbo(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="ownzbsakgskpznvriwbo_heatmap_content" style="display:flex;">
#             <div id="ownzbsakgskpznvriwbo_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="ownzbsakgskpznvriwbo_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="ownzbsakgskpznvriwbo_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="ownzbsakgskpznvriwbo_input_node_14_container" style="display:inline;text-align:center"><div id="ownzbsakgskpznvriwbo_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ownzbsakgskpznvriwbo_input_node_14_content" style="display:inline;"><div id="ownzbsakgskpznvriwbo_input_node_12_container" style="display:inline;text-align:center"><div id="ownzbsakgskpznvriwbo_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ownzbsakgskpznvriwbo_input_node_12_content" style="display:inline;"><div id="ownzbsakgskpznvriwbo_input_node_8_container" style="display:inline;text-align:center"><div id="ownzbsakgskpznvriwbo_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ownzbsakgskpznvriwbo_input_node_8_content" style="display:inline;"><div id="ownzbsakgskpznvriwbo_input_node_0_container" style="display:inline;text-align:center"><div id="ownzbsakgskpznvriwbo_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ownzbsakgskpznvriwbo_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: d
# <br/><b>7th instance:</b><br/>
#     <script>
#         function selectVizType_xnqgvlofcictjbexxhwv(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("xnqgvlofcictjbexxhwv_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('xnqgvlofcictjbexxhwv_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('xnqgvlofcictjbexxhwv_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="xnqgvlofcictjbexxhwv_viz_container">
#       <div id="xnqgvlofcictjbexxhwv_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="xnqgvlofcictjbexxhwv_viz_type" onchange="selectVizType_xnqgvlofcictjbexxhwv(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="xnqgvlofcictjbexxhwv_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "xnqgvlofcictjbexxhwv_saliency_plot_container" class="xnqgvlofcictjbexxhwv_viz_container" style="display:none">
#
#         <div id="nvbuuuafszruakksmrcz_saliency_plot" class="nvbuuuafszruakksmrcz_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
 136.0, 229.0, 0.22749059219647463)">-0.132</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5349178055060406)">-0.305</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.108</th><th style="background:rgba(30.0, 136.0, 229.0, 0.23537334125569417)">-0.135</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.032</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.206</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "xnqgvlofcictjbexxhwv_heatmap_container" class="xnqgvlofcictjbexxhwv_viz_container">
#
#         <div id="voagfmedjcpcwnyzgzzq_heatmap" class="voagfmedjcpcwnyzgzzq_viz_content">
#           <div id="voagfmedjcpcwnyzgzzq_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="voagfmedjcpcwnyzgzzq_alignment" onchange="selectAlignment_voagfmedjcpcwnyzgzzq(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="voagfmedjcpcwnyzgzzq_heatmap_content" style="display:flex;">
#             <div id="voagfmedjcpcwnyzgzzq_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="voagfmedjcpcwnyzgzzq_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="voagfmedjcpcwnyzgzzq_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="voagfmedjcpcwnyzgzzq_input_node_14_container" style="display:inline;text-align:center"><div id="voagfmedjcpcwnyzgzzq_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="voagfmedjcpcwnyzgzzq_input_node_14_content" style="display:inline;"><div id="voagfmedjcpcwnyzgzzq_input_node_12_container" style="display:inline;text-align:center"><div id="voagfmedjcpcwnyzgzzq_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="voagfmedjcpcwnyzgzzq_input_node_12_content" style="display:inline;"><div id="voagfmedjcpcwnyzgzzq_input_node_8_container" style="display:inline;text-align:center"><div id="voagfmedjcpcwnyzgzzq_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="voagfmedjcpcwnyzgzzq_input_node_8_content" style="display:inline;"><div id="voagfmedjcpcwnyzgzzq_input_node_0_container" style="display:inline;text-align:center"><div id="voagfmedjcpcwnyzgzzq_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="voagfmedjcpcwnyzgzzq_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default

# %% [markdown]
# To view what input tokens impact (positively/negatively) the liklihood of generating the word "vodka", we plot the global token importances the word "vodka". <br><br>
#
# Voila! Russians love their vodka, dont they? :)

# %%
shap.plots.bar(shap_values[...,"vodka"])
