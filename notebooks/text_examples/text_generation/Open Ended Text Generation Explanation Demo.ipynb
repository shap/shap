# %% [markdown]
# # Text to Text Explanation: Open Ended Text Generation Using GPT2

# %% [markdown]
# This notebook demonstrates how to get explanations for the output of gpt2 used for open ended text generation. In this demo, we use the pretrained gpt2 model provided by hugging face (https://huggingface.co/gpt2) to explain the generated text by gpt2. We further showcase how to get explanations for custom output generated text and plot global input token importances for any output generated token.

# %%
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM
import shap
import torch

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model =  AutoModelForCausalLM.from_pretrained("gpt2").cuda()

# %% [markdown]
# Below, we set certain model configurations. We need to define if the model is a decoder or encoder-decoder.
# This can be set through the 'is_decoder' or 'is_encoder_decoder' param in model's config file.
# We can also set custom model generation parameters which will be used during the output text generation decoding process.

# %%
# set model decoder to true
model.config.is_decoder=True
# set text-generation params under task_specific_params
model.config.task_specific_params["text-generation"] = {
    "do_sample": True,
    "max_length": 50,
    "temperature": 0.7,
    "top_k": 50,
    "no_repeat_ngram_size": 2
  }

# %% [markdown]
# ### Define initial text

# %%
s = ['I enjoy walking with my cute dog']

# %% [markdown]
# ### Create an explainer object

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# Using pad_token, but it is not set yet.
# explainers.Partition is still in an alpha state, so use with caution...

# %% [markdown]
# ### Compute shap values

# %%
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence

# %% [markdown]
# ### Visualize shap explanations

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_nazpsbxlvrhhomhivoip(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("nazpsbxlvrhhomhivoip_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('nazpsbxlvrhhomhivoip_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('nazpsbxlvrhhomhivoip_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="nazpsbxlvrhhomhivoip_viz_container">
#       <div id="nazpsbxlvrhhomhivoip_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="nazpsbxlvrhhomhivoip_viz_type" onchange="selectVizType_nazpsbxlvrhhomhivoip(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="nazpsbxlvrhhomhivoip_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "nazpsbxlvrhhomhivoip_saliency_plot_container" class="nazpsbxlvrhhomhivoip_viz_container" style="display:none">
#
#         <div id="cplarioiqfspoclrfynk_saliency_plot" class="cplarioiqfspoclrfynk_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.331</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.171</th></tr><tr><th>friend</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.078</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.289</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14078035254505847)">0.519</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1723113487819369)">-0.63</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.371</th><th style="background:rgba(30.0, 136.0, 229.0, 0.014656367597544028)">-0.06</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.436</th></tr><tr><th>.</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.285</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.148</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.024</th><th style="background:rgba(255.0, 13.0, 87 ...

# %% [markdown]
# ### Another example...

# %%
s=['Scientists confirmed the worst possible outcome: the massive asteroid will collide with Earth']

# %%
explainer = shap.Explainer(model,tokenizer)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %%
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_cwhxjtqkxzqhtzexcltd(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("cwhxjtqkxzqhtzexcltd_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('cwhxjtqkxzqhtzexcltd_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('cwhxjtqkxzqhtzexcltd_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="cwhxjtqkxzqhtzexcltd_viz_container">
#       <div id="cwhxjtqkxzqhtzexcltd_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="cwhxjtqkxzqhtzexcltd_viz_type" onchange="selectVizType_cwhxjtqkxzqhtzexcltd(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="cwhxjtqkxzqhtzexcltd_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "cwhxjtqkxzqhtzexcltd_saliency_plot_container" class="cwhxjtqkxzqhtzexcltd_viz_container" style="display:none">
#
#         <div id="eeiqgnjpbfrpikeibvpp_saliency_plot" class="eeiqgnjpbfrpikeibvpp_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
gba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.025</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.497</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.027</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.125</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.034</th></tr><tr><th>.</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.413</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.395</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.196</th><th style="background:rgba(255.0, 13.0, 87.0, 0.132897 ...

# %% [markdown]
# ##  Custom text generation and debugging biased outputs

# %% [markdown]
# Below we demonstrate the process of how to explain the liklihood of generating a particular output sentence given an input sentence using the model. <br><br>
# For example, we ask a question:<br>
# Which country's inhabitant (target) in the sentence "I know many people who are [<b>target</b>]." would have a high liklilhood of generating the token "vodka" in the output sentence "They love their <b>vodka</b>!" ?
# <br><br>
# For this, we first define input-output sentence pairs

# %%
# define input
x = [
    "I know many people who are Russian.",
    "I know many people who are Greek.",
    "I know many people who are Australian.",
    "I know many people who are American.",
    "I know many people who are Italian.",
    "I know many people who are Spanish.",
    "I know many people who are German.",
    "I know many people who are Indian."
]

# %%
# define output
y = [
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!"
]

# %% [markdown]
# We wrap the model with a Teacher Forcing scoring class and create a Text masker

# %%
teacher_forcing_model = shap.models.TeacherForcing(model, tokenizer)
masker = shap.maskers.Text(tokenizer, mask_token = "...", collapse_mask_token=True)

# %% [markdown]
# Create an explainer...

# %%
explainer = shap.Explainer(teacher_forcing_model,masker)
# Out:
# explainers.Partition is still in an alpha state, so use with caution...

# %% [markdown]
# Generate SHAP explanation values!

# %%
shap_values = explainer(x, y)

# %% [markdown]
# Now that we have generated the SHAP values, we can have a look at the contribution of tokens in the input driving the token "vodka" in the output sentence using the text plot. <br><br>
# <b>Note:</b> The red color indicates a positive contribution while the blue color indicates negative contribution and the intensity of the color shows its strength in the respective direction.

# %%
shap.plots.text(shap_values)
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_parcpkkskgqmmnluckvn(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("parcpkkskgqmmnluckvn_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('parcpkkskgqmmnluckvn_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('parcpkkskgqmmnluckvn_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="parcpkkskgqmmnluckvn_viz_container">
#       <div id="parcpkkskgqmmnluckvn_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="parcpkkskgqmmnluckvn_viz_type" onchange="selectVizType_parcpkkskgqmmnluckvn(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="parcpkkskgqmmnluckvn_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "parcpkkskgqmmnluckvn_saliency_plot_container" class="parcpkkskgqmmnluckvn_viz_container" style="display:none">
#
#         <div id="jdyawpwwamizcmbtqfer_saliency_plot" class="jdyawpwwamizcmbtqfer_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Russian</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1328976034858387)">-0.377</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.158</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.157</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.124</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.164</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.341</th><th style="background:rgba(30.0, 136.0, 229.0, 0.25113883937413345)">-0.695</th><th style="background:rgba(255.0, 13.0, 87.0, 0.07771836007130124)">0.222</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.03830461477520289)">0.126</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.448</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.248</th><th style="background:rgba(255.0, 13.0, 87.0, 0.16442859972271742)">0.45</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.057</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.023</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.015</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.143</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.069</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.088</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.297</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.144</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.159</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.25</th><th style="background:rgba(30.0, 136.0, 229.0, 0.006773618538324436)">-0.022</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.07</th></tr><tr><th>vodka</th><th style="background:rgba(255.0, 13.0, 87.0, 0.00677361853832443)">0.036</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.013</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.132</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.021</th><th style="background:rgba(30.0, 136.0, 229.0, 0.014656367597544028)">-0.044</th><th style="background:rgba(30.0, 136.0, 229.0, 0.05407011289364222)">-0.151</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">2.743</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.076</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1565458506634977)">-0.449</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.182</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.125</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.309</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.142</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03042186571598325)">-0.096</th><th style="background:rgba(255.0, 13.0, 87.0, 0.10136660724896006)">0.282</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.147</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "parcpkkskgqmmnluckvn_heatmap_container" class="parcpkkskgqmmnluckvn_viz_container">
#
#         <div id="jakpxamxbpvbxcoqklls_heatmap" class="jakpxamxbpvbxcoqklls_viz_content">
#           <div id="jakpxamxbpvbxcoqklls_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="jakpxamxbpvbxcoqklls_alignment" onchange="selectAlignment_jakpxamxbpvbxcoqklls(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="jakpxamxbpvbxcoqklls_heatmap_content" style="display:flex;">
#             <div id="jakpxamxbpvbxcoqklls_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="jakpxamxbpvbxcoqklls_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="jakpxamxbpvbxcoqklls_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="jakpxamxbpvbxcoqklls_input_node_14_container" style="display:inline;text-align:center"><div id="jakpxamxbpvbxcoqklls_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jakpxamxbpvbxcoqklls_input_node_14_content" style="display:inline;"><div id="jakpxamxbpvbxcoqklls_input_node_12_container" style="display:inline;text-align:center"><div id="jakpxamxbpvbxcoqklls_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jakpxamxbpvbxcoqklls_input_node_12_content" style="display:inline;"><div id="jakpxamxbpvbxcoqklls_input_node_8_container" style="display:inline;text-align:center"><div id="jakpxamxbpvbxcoqklls_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jakpxamxbpvbxcoqklls_input_node_8_content" style="display:inline;"><div id="jakpxamxbpvbxcoqklls_input_node_0_container" style="display:inline;text-align:center"><div id="jakpxamxbpvbxcoqklls_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jakpxamxbpvbxcoqklls_input_node_0_content"s
# <br/><b>1st instance:</b><br/>
#     <script>
#         function selectVizType_uutjcmlciaxeienwrzde(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("uutjcmlciaxeienwrzde_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('uutjcmlciaxeienwrzde_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('uutjcmlciaxeienwrzde_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="uutjcmlciaxeienwrzde_viz_container">
#       <div id="uutjcmlciaxeienwrzde_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="uutjcmlciaxeienwrzde_viz_type" onchange="selectVizType_uutjcmlciaxeienwrzde(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="uutjcmlciaxeienwrzde_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "uutjcmlciaxeienwrzde_saliency_plot_container" class="uutjcmlciaxeienwrzde_viz_container" style="display:none">
#
#         <div id="qhuhheecycaivblaoznd_saliency_plot" class="qhuhheecycaivblaoznd_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Greek</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3772628243216478)">-0.351</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1328976034858387)">-0.125</th><th style="background:rgba(30.0, 136.0, 229.0, 0.25902158843335304)">-0.242</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.149</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.182</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4087938205585263)">0.376</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="valgepyckgkowpzdsnuz_alignment" onchange="selectAlignment_valgepyckgkowpzdsnuz(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="valgepyckgkowpzdsnuz_heatmap_content" style="display:flex;">
#             <div id="valgepyckgkowpzdsnuz_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="valgepyckgkowpzdsnuz_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="valgepyckgkowpzdsnuz_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="valgepyckgkowpzdsnuz_input_node_14_container" style="display:inline;text-align:center"><div id="valgepyckgkowpzdsnuz_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="valgepyckgkowpzdsnuz_input_node_14_content" style="display:inline;"><div id="valgepyckgkowpzdsnuz_input_node_12_container" style="display:inline;text-align:center"><div id="valgepyckgkowpzdsnuz_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="valgepyckgkowpzdsnuz_input_node_12_content" style="display:inline;"><div id="valgepyckgkowpzdsnuz_input_node_8_container" style="display:inline;text-align:center"><div id="valgepyckgkowpzdsnuz_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="valgepyckgkowpzdsnuz_input_node_8_content" style="display:inline;"><div id="valgepyckgkowpzdsnuz_input_node_0_container" style="display:inline;text-align:center"><div id="valgepyckgkowpzdsnuz_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="valgepyckgkowpzdsnuz_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; p
# <br/><b>2nd instance:</b><br/>
#     <script>
#         function selectVizType_epspeapzvkxxmccafnux(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("epspeapzvkxxmccafnux_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('epspeapzvkxxmccafnux_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('epspeapzvkxxmccafnux_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="epspeapzvkxxmccafnux_viz_container">
#       <div id="epspeapzvkxxmccafnux_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="epspeapzvkxxmccafnux_viz_type" onchange="selectVizType_epspeapzvkxxmccafnux(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="epspeapzvkxxmccafnux_content" style="padding:15px;border-style:solid;margin:5px;">
, 136.0, 229.0, 0.865993265993266)">-0.635</th><th style="background:rgba(30.0, 136.0, 229.0, 0.40091107149930677)">-0.297</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.003</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.621628045157457)">-0.455</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.201</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.14</th><th style="background:rgba(30.0, 136.0, 229.0, 0.42455931867696567)">-0.315</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.141</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1959595959595959)">-0.149</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29055258467023165)">0.217</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.172</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "epspeapzvkxxmccafnux_heatmap_container" class="epspeapzvkxxmccafnux_viz_container">
#
#         <div id="jgcuxbhuqjxysugywrcg_heatmap" class="jgcuxbhuqjxysugywrcg_viz_content">
#           <div id="jgcuxbhuqjxysugywrcg_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="jgcuxbhuqjxysugywrcg_alignment" onchange="selectAlignment_jgcuxbhuqjxysugywrcg(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="jgcuxbhuqjxysugywrcg_heatmap_content" style="display:flex;">
#             <div id="jgcuxbhuqjxysugywrcg_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="jgcuxbhuqjxysugywrcg_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="jgcuxbhuqjxysugywrcg_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="jgcuxbhuqjxysugywrcg_input_node_14_container" style="display:inline;text-align:center"><div id="jgcuxbhuqjxysugywrcg_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jgcuxbhuqjxysugywrcg_input_node_14_content" style="display:inline;"><div id="jgcuxbhuqjxysugywrcg_input_node_12_container" style="display:inline;text-align:center"><div id="jgcuxbhuqjxysugywrcg_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jgcuxbhuqjxysugywrcg_input_node_12_content" style="display:inline;"><div id="jgcuxbhuqjxysugywrcg_input_node_8_container" style="display:inline;text-align:center"><div id="jgcuxbhuqjxysugywrcg_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jgcuxbhuqjxysugywrcg_input_node_8_content" style="display:inline;"><div id="jgcuxbhuqjxysugywrcg_input_node_0_container" style="display:inline;text-align:center"><div id="jgcuxbhuqjxysugywrcg_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jgcuxbhuqjxysugywrcg_input_node_0_content"style='display: inline; background:transparent
# <br/><b>3rd instance:</b><br/>
#     <script>
#         function selectVizType_guswquhzsfvapvfrmwce(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("guswquhzsfvapvfrmwce_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('guswquhzsfvapvfrmwce_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('guswquhzsfvapvfrmwce_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="guswquhzsfvapvfrmwce_viz_container">
#       <div id="guswquhzsfvapvfrmwce_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="guswquhzsfvapvfrmwce_viz_type" onchange="selectVizType_guswquhzsfvapvfrmwce(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="guswquhzsfvapvfrmwce_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "guswquhzsfvapvfrmwce_saliency_plot_container" class="guswquhzsfvapvfrmwce_viz_container" style="display:none">
#
#         <div id="aptffqhvstuyaaizcakm_saliency_plot" class="aptffqhvstuyaaizcakm_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>American</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5191523073876015)">-0.439</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21960784313725487)">-0.185</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.163</th><th style="background:rgba(255.0, 13.0, 87.0, 0.15654585066349747)">0.134</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.099</th><th style="background:rgba(255.0, 13.0, 87.0, 0.306318082788671)">0.262</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-0.84</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2826698356110118)">0.237</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.13</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5349178055060405)">0.451</th><th style="background:rgba(255.0, 13.0, 87.0, 0.20384234501881549)">0.174</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4718558130322837)">0.398</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.006</th><th style="background:rgba(30.0, 136.0, 229.0, 0.12501485442661905)">-0.11</th><th style="background:rgba(255.0, 13.0, 87.0, 0.6531590413943356)">0.548</th><th style="background:rgba(30.0, 136.0, 229.0, 0.18019409784115656)">-0.156</th></tr><tr><th>their</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.04</th><th style="background:rgba(255.0, 13.0, 87.0, 0.12501485442661908)">0.109</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4087938205585263)">0.343</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2511388393741335)">0.212</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1880768469003763)">0.164</th><th style="background:rgba(255.0, 13.0, 87.0, 0.32208358090711037)">0.272</th><th style="background:rgba(255.0, 13.0, 87.0, 0.44032481679540497)">0.374</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.024</th></tr><tr><th>vodka</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.094</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.055</th><th style="background:rgba(30.0, 136.0, 229.0, 0.4324420677361853)">-0.366</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5112695583283818)">-0.43</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06983561101208147)">-0.064</th><th style="background:rgba(30.0, 136.0, 229.0, 0.597979797979798)">-0.501</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5033868092691621)">-0.423</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.099</th></tr><tr><th>!</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5743315508021389)">-0.484</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21172509407803525)">-0.182</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14866310160427798)">-0.129</th><th style="background:rgba(30.0, 136.0, 229.0, 0.40091107149930677)">-0.34</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1565458506634977)">-0.136</th><th style="background:rgba(30.0, 136.0, 229.0, 0.16442859972271748)">-0.141</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1328976034858387)">-0.114</th><th style="background:rgba(255.0, 13.0, 87.0, 0.26690433749257286)">0.229</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "guswquhzsfvapvfrmwce_heatmap_container" class="guswquhzsfvapvfrmwce_viz_container">
#
#         <div id="cvbmcdtrncquqxagsqta_heatmap" class="cvbmcdtrncquqxagsqta_viz_content">
#           <div id="cvbmcdtrncquqxagsqta_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="cvbmcdtrncquqxagsqta_alignment" onchange="selectAlignment_cvbmcdtrncquqxagsqta(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="cvbmcdtrncquqxagsqta_heatmap_content" style="display:flex;">
#             <div id="cvbmcdtrncquqxagsqta_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="cvbmcdtrncquqxagsqta_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="cvbmcdtrncquqxagsqta_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="cvbmcdtrncquqxagsqta_input_node_14_container" style="display:inline;text-align:center"><div id="cvbmcdtrncquqxagsqta_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="cvbmcdtrncquqxagsqta_input_node_14_content" style="display:inline;"><div id="cvbmcdtrncquqxagsqta_input_node_12_container" style="display:inline;text-align:center"><div id="cvbmcdtrncquqxagsqta_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="cvbmcdtrncquqxagsqta_input_node_12_content" style="display:inline;"><div id="cvbmcdtrncquqxagsqta_input_node_8_container" style="display:inline;text-align:center"><div id="cvbmcdtrncquqxagsqta_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="cvbmcdtrncquqxagsqta_input_node_8_content" style="display:inline;"><div id="cvbmcdtrncquqxagsqta_input_node_0_container" style="display:inline;text-align:center"><div id="cvbmcdtrncquqxagsqta_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="cvbmcdtrncquqxagsqta_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px
# <br/><b>4th instance:</b><br/>
#     <script>
#         function selectVizType_bwjdzwawapzfpzatalpt(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("bwjdzwawapzfpzatalpt_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('bwjdzwawapzfpzatalpt_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('bwjdzwawapzfpzatalpt_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="bwjdzwawapzfpzatalpt_viz_container">
#       <div id="bwjdzwawapzfpzatalpt_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="bwjdzwawapzfpzatalpt_viz_type" onchange="selectVizType_bwjdzwawapzfpzatalpt(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="bwjdzwawapzfpzatalpt_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "bwjdzwawapzfpzatalpt_saliency_plot_container" class="bwjdzwawapzfpzatalpt_viz_container" style="display:none">
#
#         <div id="cmohyxsvwrtyatijgcuq_saliency_plot" class="cmohyxsvwrtyatijgcuq_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
0, 136.0, 229.0, 0.1723113487819369)">-0.172</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.11</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.266</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.139</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.079</th><th style="background:rgba(255.0, 13.0, 87.0, 0.5270350564468211)">0.508</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1959595959595959)">0.193</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "bwjdzwawapzfpzatalpt_heatmap_container" class="bwjdzwawapzfpzatalpt_viz_container">
#
#         <div id="myzcnjkjfwfnfqwibnqg_heatmap" class="myzcnjkjfwfnfqwibnqg_viz_content">
#           <div id="myzcnjkjfwfnfqwibnqg_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="myzcnjkjfwfnfqwibnqg_alignment" onchange="selectAlignment_myzcnjkjfwfnfqwibnqg(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="myzcnjkjfwfnfqwibnqg_heatmap_content" style="display:flex;">
#             <div id="myzcnjkjfwfnfqwibnqg_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="myzcnjkjfwfnfqwibnqg_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="myzcnjkjfwfnfqwibnqg_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="myzcnjkjfwfnfqwibnqg_input_node_14_container" style="display:inline;text-align:center"><div id="myzcnjkjfwfnfqwibnqg_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="myzcnjkjfwfnfqwibnqg_input_node_14_content" style="display:inline;"><div id="myzcnjkjfwfnfqwibnqg_input_node_12_container" style="display:inline;text-align:center"><div id="myzcnjkjfwfnfqwibnqg_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="myzcnjkjfwfnfqwibnqg_input_node_12_content" style="display:inline;"><div id="myzcnjkjfwfnfqwibnqg_input_node_8_container" style="display:inline;text-align:center"><div id="myzcnjkjfwfnfqwibnqg_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="myzcnjkjfwfnfqwibnqg_input_node_8_content" style="display:inline;"><div id="myzcnjkjfwfnfqwibnqg_input_node_0_container" style="display:inline;text-align:center"><div id="myzcnjkjfwfnfqwibnqg_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="myzcnjkjfwfnfqwibnqg_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: def
# <br/><b>5th instance:</b><br/>
#     <script>
#         function selectVizType_mwpybemccorntqnjduwc(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("mwpybemccorntqnjduwc_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('mwpybemccorntqnjduwc_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('mwpybemccorntqnjduwc_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="mwpybemccorntqnjduwc_viz_container">
#       <div id="mwpybemccorntqnjduwc_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="mwpybemccorntqnjduwc_viz_type" onchange="selectVizType_mwpybemccorntqnjduwc(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="mwpybemccorntqnjduwc_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "mwpybemccorntqnjduwc_saliency_plot_container" class="mwpybemccorntqnjduwc_viz_container" style="display:none">
#
#         <div id="ouxooawvcqeqgyiitple_saliency_plot" class="ouxooawvcqeqgyiitple_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>Spanish</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3220835809071103)">-0.399</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.15</th><th style="background:rgba(30.0, 136.0, 229.0, 0.18019409784115656)">-0.225</th><th style="background:rgba(255.0, 13.0, 87.0, 0.08560110913052081)">0.106</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.284</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4245593186769657)">0.519</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-1.223</th><th style="background:rgba(255.0, 13.0, 87.0, 0.2117250940780353)">0.261</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1171321053673995)">0.149</th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.526</th><th style="background:rgba(255.0, 13.0, 87.0, 0.18019409784115661)">0.225</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3457318280847692)">0.427</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.021</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.048</th><th style="background:rgba(255.0, 13.0, 87.0, 0.3457318280847692)">0.428</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.178</th></tr><tr><th>their
#                 Input Text
#               </div>
#               <div id="jhbcrnhmppfrnvtlysdx_input_content" style="margin:5px;font-family:sans-serif;">
# ...
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("mmhnpsamuoqwvtujjpfs_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('mmhnpsamuoqwvtujjpfs_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('mmhnpsamuoqwvtujjpfs_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="mmhnpsamuoqwvtujjpfs_viz_container">
#       <div id="mmhnpsamuoqwvtujjpfs_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="mmhnpsamuoqwvtujjpfs_viz_type" onchange="selectVizType_mmhnpsamuoqwvtujjpfs(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="mmhnpsamuoqwvtujjpfs_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "mmhnpsamuoqwvtujjpfs_saliency_plot_container" class="mmhnpsamuoqwvtujjpfs_viz_container" style="display:none">
#
#         <div id="btxcixwpyrymphclwsyl_saliency_plot" class="btxcixwpyrymphclwsyl_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th>I </th><th>know </th><th>many </th><th>people </th><th>who </th><th>are </th><th>German</th><th>.</th></tr><tr><th>They</th><th style="background:rgba(30.0, 136.0, 229.0, 0.36938007526242816)">-0.38</th><th style="background:rgba(30.0, 136.0, 229.0, 0.11713210536739943)">-0.125</th><th style="background:rgba(30.0, 136.0, 229.0, 0.27478708655179246)">-0.282</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.138</th><th style="background:rgba(255.0, 13.0, 87.0, 0.1880768469003763)">0.192</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4087938205585263)">0.418</th><th style="background:rgba(30.0, 136.0, 229.0, 1.0)">-1.018</th><th style="background:rgba(255.0, 13.0, 87.0, 0.29843533372945136)">0.307</th></tr><tr><th>love</th><th style="background:rgba(255.0, 13.0, 87.0, 0.13289760348583876)">0.135</th><th style="background:rgba(255.0, 13.0, 87.0, 0.4718558130322837)">0.482</th><th style="background:rgba(255.0, 13.0, 87.0, 0.22749059219647458)">0.231</th><th style="background:rgba(255.0, 13.0, 87.0, 0.43244206773618543)">0.44</th><th style="background:rgba(255.0, 13.0, 87.0, 0.04618736383442265)">0.051</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597
#             <div id="nnrxpphknqvtubbakafw_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="nnrxpphknqvtubbakafw_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="nnrxpphknqvtubbakafw_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="nnrxpphknqvtubbakafw_input_node_14_container" style="display:inline;text-align:center"><div id="nnrxpphknqvtubbakafw_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="nnrxpphknqvtubbakafw_input_node_14_content" style="display:inline;"><div id="nnrxpphknqvtubbakafw_input_node_12_container" style="display:inline;text-align:center"><div id="nnrxpphknqvtubbakafw_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="nnrxpphknqvtubbakafw_input_node_12_content" style="display:inline;"><div id="nnrxpphknqvtubbakafw_input_node_8_container" style="display:inline;text-align:center"><div id="nnrxpphknqvtubbakafw_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="nnrxpphknqvtubbakafw_input_node_8_content" style="display:inline;"><div id="nnrxpphknqvtubbakafw_input_node_0_container" style="display:inline;text-align:center"><div id="nnrxpphknqvtubbakafw_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="nnrxpphknqvtubbakafw_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: d
# <br/><b>7th instance:</b><br/>
#     <script>
#         function selectVizType_pvohogjlfrockfneicpb(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("pvohogjlfrockfneicpb_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('pvohogjlfrockfneicpb_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('pvohogjlfrockfneicpb_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="pvohogjlfrockfneicpb_viz_container">
#       <div id="pvohogjlfrockfneicpb_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="pvohogjlfrockfneicpb_viz_type" onchange="selectVizType_pvohogjlfrockfneicpb(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="pvohogjlfrockfneicpb_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "pvohogjlfrockfneicpb_saliency_plot_container" class="pvohogjlfrockfneicpb_viz_container" style="display:none">
#
#         <div id="yvttzwlxhajqpxzvwbpt_saliency_plot" class="yvttzwlxhajqpxzvwbpt_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
 136.0, 229.0, 0.22749059219647463)">-0.132</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5349178055060406)">-0.305</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1880768469003762)">-0.108</th><th style="background:rgba(30.0, 136.0, 229.0, 0.23537334125569417)">-0.135</th><th style="background:rgba(255.0, 13.0, 87.0, 0.05407011289364243)">0.032</th><th style="background:rgba(255.0, 13.0, 87.0, 0.36149732620320857)">0.206</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "pvohogjlfrockfneicpb_heatmap_container" class="pvohogjlfrockfneicpb_viz_container">
#
#         <div id="hksxdsbadzurrrvsjkwc_heatmap" class="hksxdsbadzurrrvsjkwc_viz_content">
#           <div id="hksxdsbadzurrrvsjkwc_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="hksxdsbadzurrrvsjkwc_alignment" onchange="selectAlignment_hksxdsbadzurrrvsjkwc(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="hksxdsbadzurrrvsjkwc_heatmap_content" style="display:flex;">
#             <div id="hksxdsbadzurrrvsjkwc_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="hksxdsbadzurrrvsjkwc_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="hksxdsbadzurrrvsjkwc_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="hksxdsbadzurrrvsjkwc_input_node_14_container" style="display:inline;text-align:center"><div id="hksxdsbadzurrrvsjkwc_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hksxdsbadzurrrvsjkwc_input_node_14_content" style="display:inline;"><div id="hksxdsbadzurrrvsjkwc_input_node_12_container" style="display:inline;text-align:center"><div id="hksxdsbadzurrrvsjkwc_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hksxdsbadzurrrvsjkwc_input_node_12_content" style="display:inline;"><div id="hksxdsbadzurrrvsjkwc_input_node_8_container" style="display:inline;text-align:center"><div id="hksxdsbadzurrrvsjkwc_input_node_8_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hksxdsbadzurrrvsjkwc_input_node_8_content" style="display:inline;"><div id="hksxdsbadzurrrvsjkwc_input_node_0_container" style="display:inline;text-align:center"><div id="hksxdsbadzurrrvsjkwc_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hksxdsbadzurrrvsjkwc_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default

# %% [markdown]
# To view what input tokens impact (positively/negatively) the liklihood of generating the word "vodka", we plot the global token importances the word "vodka". <br><br>
#
# Voila! Russians love their vodka, dont they? :)

# %%
shap.plots.bar(shap_values[...,"vodka"])
