# %% [markdown]
# # Text to Multiclass Explanation: Emotion Classification Example

# %% [markdown]
# This notebook demonstrates how to use the partition explainer for multiclass scenario with text data and visualize feature attributions towards individual classes. For computing shap values for a multiclass scenario, it uses the partition explainer over the text data and computes attribution for a feature towards a given class based on its marginal contribution towards the difference in the one vs all logit for the respective class from its base value.
#
# Below we walkthrough an example demonstrating explanation of a text classfication model (https://huggingface.co/nateraw/bert-base-uncased-emotion) which in this case is BERT fine-tuned on the emotion dataset (https://huggingface.co/datasets/emotion) provided by hugging face to classify a sentence among six classes of emotions: joy, sadness, anger, fear, love and surprise.

# %%
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import shap
import scipy as sp
from datasets import load_dataset
import torch

# %% [markdown]
# ### Load data

# %%
dataset  = load_dataset("emotion", split = "train")
data = pd.DataFrame({'text':dataset['text'],'emotion':dataset['label']})
# Out:
# Using custom data configuration default
# Reusing dataset emotion (/home/slundberg/.cache/huggingface/datasets/emotion/default/0.0.0/aa34462255cd487d04be8387a2d572588f6ceee23f784f37365aa714afeb8fe6)

# %%
data.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated        0
# 1  i can go from feeling so hopeless to so damned...        0
# 2   im grabbing a minute to post i feel greedy wrong        3
# 3  i am ever feeling nostalgic about the fireplac...        2
# 4                               i am feeling grouchy        3

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion",use_fast=True)
model = AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion").cuda()

# %%
# set mapping between label and id
id2label = model.config.id2label
label2id = model.config.label2id
labels = sorted(label2id, key=label2id.get)

# %% [markdown]
# ### Distribution of emotion labels

# %%
ax = data.emotion.map(id2label).value_counts().plot.bar()

# %% [markdown]
# ### Define function

# %%
def f(x):
    tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=128,truncation=True) for v in x]).cuda()
    attention_mask = (tv!=0).type(torch.int64).cuda()
    outputs = model(tv,attention_mask=attention_mask)[0].detach().cpu().numpy()
    scores = (np.exp(outputs).T / np.exp(outputs).sum(-1)).T
    val = sp.special.logit(scores) 
    return val

# %% [markdown]
# ### Create an explainer object

# %%
explainer = shap.Explainer(f,tokenizer,output_names=labels)

# %% [markdown]
# ### Compute SHAP values

# %%
shap_values = explainer(data['text'][0:50])

# %% [markdown]
# ### Top words contributing to emotion class: joy

# %%
shap.plots.bar(shap_values[:,:,"joy"].mean(0))

# %% [markdown]
# ### Top words positively contributing to emotion class: joy

# %%
shap.plots.bar(shap_values[:,:,"joy"].mean(0), order=shap.Explanation.argsort.flip)

# %% [markdown]
# ### Top words negatively contributing to emotion class: joy

# %%
shap.plots.bar(shap_values[:,:,"joy"].mean(0), order=shap.Explanation.argsort)

# %% [markdown]
# ### Top words positively contributing to emotion class: surprise

# %%
shap.plots.bar(shap_values[:,:,"surprise"].mean(0), order=shap.Explanation.argsort.flip)

# %% [markdown]
# ### Top words negatively contributing to emotion class: surprise

# %%
shap.plots.bar(shap_values[:,:,"surprise"].mean(0), order=shap.Explanation.argsort)

# %% [markdown]
# ### Top words positively contributing to emotion class: anger

# %%
shap.plots.bar(shap_values[:,:,"anger"].mean(0), order=shap.Explanation.argsort.flip)

# %% [markdown]
# ### Top words negatively contributing to emotion class: anger

# %%
shap.plots.bar(shap_values[:,:,"anger"].mean(0), order=shap.Explanation.argsort)

# %% [markdown]
# ### Visualizing text plots over attribution of features towards a given class

# %%
shap.plots.text(shap_values[:5])
# Out:
# <br/><b>0th instance:</b><br/>
#     <script>
#         function selectVizType_dzuqovzpeixlzlgmevcr(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("dzuqovzpeixlzlgmevcr_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('dzuqovzpeixlzlgmevcr_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('dzuqovzpeixlzlgmevcr_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="dzuqovzpeixlzlgmevcr_viz_container">
#       <div id="dzuqovzpeixlzlgmevcr_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="dzuqovzpeixlzlgmevcr_viz_type" onchange="selectVizType_dzuqovzpeixlzlgmevcr(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="dzuqovzpeixlzlgmevcr_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "dzuqovzpeixlzlgmevcr_saliency_plot_container" class="dzuqovzpeixlzlgmevcr_viz_container" style="display:none">
#
#         <div id="tioqllzbwjlzdnfubyqn_saliency_plot" class="tioqllzbwjlzdnfubyqn_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th></th><th>i </th><th>didnt </th><th>feel </th><th>humiliated</th><th></th></tr><tr><th>sadness</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(255.0, 13.0, 87.0, 0.014656367597544035)">0.16</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.249</th><th style="background:rgba(255.0, 13.0, 87.0, 0.02253911665676371)">0.201</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">6.901</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>joy</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.006773618538324436)">-0.055</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.238</th><th style="background:rgba(255.0, 13.0, 87.0, 0.06983561101208159)">0.511</th><th style="background:rgba(30.0, 136.0, 229.0, 0.9763517528223411)">-6.736</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>love</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.014656367597544028)">-0.115</th><th style="background:rgba(30.0, 136.0, 229.0, 0.04618736383442258)">-0.356</th><th style="background:rgba(30.0, 136.0, 229.0, 0.006773618538324436)">-0.07</th><th style="background:rgba(30.0, 136.0, 229.0, 0.6768072885719945)">-4.673</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr><tr><th>anger</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.05</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.289</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1723113487819369)">-1.233</th><th style="background:rgba(30.0, 136.0, 229.0, 0.6058625470390175)">-4.175</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr><tr><th>fear</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.03830461477520309)">-0.278</th><th style="background:rgba(255.0, 13.0, 87.0, 0.030421865715983164)">0.259</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.685</th><th style="background:rgba(30.0, 136.0, 229.0, 0.621628045157457)">-4.298</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr><tr><th>surprise</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.022539116656763607)">-0.185</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06983561101208147)">-0.489</th><th style="background:rgba(30.0, 136.0, 229.0, 0.06195286195286191)">-0.437</th><th style="background:rgba(30.0, 136.0, 229.0, 0.7556347791641909)">-5.187</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "dzuqovzpeixlzlgmevcr_heatmap_container" class="dzuqovzpeixlzlgmevcr_viz_container">
#
#         <div id="jlkjascxppczzpzqncro_heatmap" class="jlkjascxppczzpzqncro_viz_content">
#           <div id="jlkjascxppczzpzqncro_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="jlkjascxppczzpzqncro_alignment" onchange="selectAlignment_jlkjascxppczzpzqncro(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="jlkjascxppczzpzqncro_heatmap_content" style="display:flex;">
#             <div id="jlkjascxppczzpzqncro_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="jlkjascxppczzpzqncro_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="jlkjascxppczzpzqncro_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="jlkjascxppczzpzqncro_input_node_12_container" style="display:inline;text-align:center"><div id="jlkjascxppczzpzqncro_input_node_12_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jlkjascxppczzpzqncro_input_node_12_content" style="display:inline;"><div id="jlkjascxppczzpzqncro_input_node_11_container" style="display:inline;text-align:center"><div id="jlkjascxppczzpzqncro_input_node_11_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jlkjascxppczzpzqncro_input_node_11_content" style="display:inline;"><div id="jlkjascxppczzpzqncro_input_node_0_container" style="display:inline;text-align:center"><div id="jlkjascxppczzpzqncro_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="jlkjascxppczzpzqncro_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default;cursor: pointer;'onmouseover="onMouseHoverFlat_jlkjascxppczzpzqncro(this.id)" onmouseout="onMouseOutFlat_jlkjascxppczzpzqncro(this.id)" onclick="onMouseClickFlat_jlkjascxppczzpzqncro(this.id)" ></div></div><div id="jlkjascxppczzpzqncro_input_node_10_container" style="display:inline;text
# <br/><b>1st instance:</b><br/>
#     <script>
#         function selectVizType_mcntizkjdkzgbydxrbql(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("mcntizkjdkzgbydxrbql_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('mcntizkjdkzgbydxrbql_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('mcntizkjdkzgbydxrbql_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="mcntizkjdkzgbydxrbql_viz_container">
#       <div id="mcntizkjdkzgbydxrbql_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="mcntizkjdkzgbydxrbql_viz_type" onchange="selectVizType_mcntizkjdkzgbydxrbql(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="mcntizkjdkzgbydxrbql_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "mcntizkjdkzgbydxrbql_saliency_plot_container" class="mcntizkjdkzgbydxrbql_viz_container" style="display:none">
#
#         <div id="gbrtlzpxhhdzfobvinzk_saliency_plot" class="gbrtlzpxhhdzfobvinzk_viz_content">
gba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "mcntizkjdkzgbydxrbql_heatmap_container" class="mcntizkjdkzgbydxrbql_viz_container">
#
#         <div id="wtdaupjyehzfpawhiwpy_heatmap" class="wtdaupjyehzfpawhiwpy_viz_content">
#           <div id="wtdaupjyehzfpawhiwpy_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="wtdaupjyehzfpawhiwpy_alignment" onchange="selectAlignment_wtdaupjyehzfpawhiwpy(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="wtdaupjyehzfpawhiwpy_heatmap_content" style="display:flex;">
#             <div id="wtdaupjyehzfpawhiwpy_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="wtdaupjyehzfpawhiwpy_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="wtdaupjyehzfpawhiwpy_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="wtdaupjyehzfpawhiwpy_input_node_44_container" style="display:inline;text-align:center"><div id="wtdaupjyehzfpawhiwpy_input_node_44_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wtdaupjyehzfpawhiwpy_input_node_44_content" style="display:inline;"><div id="wtdaupjyehzfpawhiwpy_input_node_43_container" style="display:inline;text-align:center"><div id="wtdaupjyehzfpawhiwpy_input_node_43_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wtdaupjyehzfpawhiwpy_input_node_43_content" style="display:inline;"><div id="wtdaupjyehzfpawhiwpy_input_node_0_container" style="display:inline;text-align:center"><div id="wtdaupjyehzfpawhiwpy_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="wtdaupjyehzfpawhiwpy_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default;cursor: pointer;'onmouseover="onMouseHoverFlat_wtdaupjyehzfpawhiwpy(this.id)" onmouseout="onMouseOutFlat_wtdaupjyehzfpawhiwpy(this.id)" onclick="onMouseClickFlat_wtdaupjyehzfpawhiwpy(this.id)" ></div></di
# <br/><b>2nd instance:</b><br/>
#     <script>
#         function selectVizType_gqxgonupycvfmaffysxp(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("gqxgonupycvfmaffysxp_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('gqxgonupycvfmaffysxp_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('gqxgonupycvfmaffysxp_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="gqxgonupycvfmaffysxp_viz_container">
#       <div id="gqxgonupycvfmaffysxp_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="gqxgonupycvfmaffysxp_viz_type" onchange="selectVizType_gqxgonupycvfmaffysxp(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="gqxgonupycvfmaffysxp_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "gqxgonupycvfmaffysxp_saliency_plot_container" class="gqxgonupycvfmaffysxp_viz_container" style="display:none">
#
#         <div id="nauwkibavnvynuuvadag_saliency_plot" class="nauwkibavnvynuuvadag_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th></th><th>im grabbing a minute </th><th>to post i feel </th><th>greedy </th><th>wrong</th><th></th></tr><tr><th>sadness</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1565458506634977)">-0.609</th><th style="background:rgba(30.0, 136.0, 229.0, 0.1959595959595959)">-0.774</th><th style="background:rgba(30.0, 136.0, 229.0, 0.6531590413943356)">-2.5</th><th style="background:rgba(30.0, 136.0, 229.0, 0.12501485442661905)">-0.486</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>joy</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.09348385818974048)">-0.386</th><th style="background:rgba(255.0, 13.0, 87.0, 0.09348385818974037)">0.386</th><th style="background:rgba(30.0, 136.0, 229.0, 0.9132897603485839)">-3.488</th><th style="background:rgba(30.0, 136.0, 229.0, 0.7477520301049712)">-2.863</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>love</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.10924935630817977)">-0.444</th><th style="background:rgba(30.0, 136.0, 229.0, 0.25902158843335304)">-0.986</th><th style="background:rgba(30.0, 136.0, 229.0, 0.36938007526242816)">-1.419</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3220835809071103)">-1.236</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>anger</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(255.0, 13.0, 87.0, 0.14866310160427795)">0.58</th><th style="background:rgba(30.0, 136.0, 229.0, 0.21960784313725487)">-0.86</th><th style="background:rgba(255.0, 13.0, 87.0, 1.0)">3.824</th><th style="background:rgba(255.0, 13.0, 87.0, 0.6295107942166767)">2.417</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr><tr><th>fear</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.07771836007130117)">-0.318</th><th style="background:rgba(30.0, 136.0, 229.0, 0.08560110913052085)">-0.354</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5033868092691621)">-1.936</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3299663299663299)">-1.272</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th></tr><tr><th>surprise</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.554</th><th style="background:rgba(30.0, 136.0, 229.0, 0.23537334125569417)">-0.923</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5112695583283818)">-1.971</th><th style="background:rgba(30.0, 136.0, 229.0, 0.30631808278867095)">-1.19</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "gqxgonupycvfmaffysxp_heatmap_container" class="gqxgonupycvfmaffysxp_viz_container">
#
#         <div id="ocqokeepvdvmtkmpzvup_heatmap" class="ocqokeepvdvmtkmpzvup_viz_content">
#           <div id="ocqokeepvdvmtkmpzvup_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="ocqokeepvdvmtkmpzvup_alignment" onchange="selectAlignment_ocqokeepvdvmtkmpzvup(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="ocqokeepvdvmtkmpzvup_heatmap_content" style="display:flex;">
#             <div id="ocqokeepvdvmtkmpzvup_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="ocqokeepvdvmtkmpzvup_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="ocqokeepvdvmtkmpzvup_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="ocqokeepvdvmtkmpzvup_input_node_22_container" style="display:inline;text-align:center"><div id="ocqokeepvdvmtkmpzvup_input_node_22_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ocqokeepvdvmtkmpzvup_input_node_22_content" style="display:inline;"><div id="ocqokeepvdvmtkmpzvup_input_node_21_container" style="display:inline;text-align:center"><div id="ocqokeepvdvmtkmpzvup_input_node_21_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ocqokeepvdvmtkmpzvup_input_node_21_content" style="display:inline;"><div id="ocqokeepvdvmtkmpzvup_input_node_0_container" style="display:inline;text-align:center"><div id="ocqokeepvdvmtkmpzvup_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="ocqokeepvdvmtkmpzvup_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default;cursor: pointer;'onmouseover="onMouseHoverFlat_ocqokeepvdvmtkmpzvup(this.id)" onmouseout="onMouseOutFlat_ocqokeepvdvmtkmpzvup(this.id)" onclick="onMouseClickFlat_ocqokeepvdvmtkmpzvup(this.id)" ></div></div><div id="ocqokeepvdvmtkmpzvup_input_node_20_container" style="display:inline;text-
# <br/><b>3rd instance:</b><br/>
#     <script>
#         function selectVizType_eohztilpctcvsqkyuluf(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("eohztilpctcvsqkyuluf_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('eohztilpctcvsqkyuluf_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('eohztilpctcvsqkyuluf_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="eohztilpctcvsqkyuluf_viz_container">
#       <div id="eohztilpctcvsqkyuluf_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="eohztilpctcvsqkyuluf_viz_type" onchange="selectVizType_eohztilpctcvsqkyuluf(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="eohztilpctcvsqkyuluf_content" style="padding:15px;border-style:solid;margin:5px;">
#           <div id = "eohztilpctcvsqkyuluf_saliency_plot_container" class="eohztilpctcvsqkyuluf_viz_container" style="display:none">
#
#         <div id="gslxpngvznmlujakktxc_saliency_plot" class="gslxpngvznmlujakktxc_viz_content">
#             <div style="margin:5px;font-family:sans-serif;font-weight:bold;">
#                 <span style="font-size: 20px;"> Saliency Plot </span>
#                 <br>
#                 x-axis: Output Text
#                 <br>
#                 y-axis: Input Text
#             </div>
#             <table border = "1" cellpadding = "5" cellspacing = "5" style="overflow-x:scroll;display:block;"><tr><th></th><th></th><th>i am ever feeling </th><th>nostal</th><th>gic </th><th>about the fireplace i will know that it is still on the property</th><th></th></tr><tr><th>sadness</th><th style="background:rgba(54.70588235294111, 122.49411764705886, 213.40784313725496, 0.0)">-0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.282669835611012)">-1.609</th><th style="background:rgba(30.0, 136.0, 229.0, 0.33784907902554956)">-1.888
#               <select name="alignment" id="hosbsxcwemqsofrxyxph_alignment" onchange="selectAlignment_hosbsxcwemqsofrxyxph(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="hosbsxcwemqsofrxyxph_heatmap_content" style="display:flex;">
#             <div id="hosbsxcwemqsofrxyxph_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="hosbsxcwemqsofrxyxph_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="hosbsxcwemqsofrxyxph_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="hosbsxcwemqsofrxyxph_input_node_42_container" style="display:inline;text-align:center"><div id="hosbsxcwemqsofrxyxph_input_node_42_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hosbsxcwemqsofrxyxph_input_node_42_content" style="display:inline;"><div id="hosbsxcwemqsofrxyxph_input_node_41_container" style="display:inline;text-align:center"><div id="hosbsxcwemqsofrxyxph_input_node_41_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hosbsxcwemqsofrxyxph_input_node_41_content" style="display:inline;"><div id="hosbsxcwemqsofrxyxph_input_node_0_container" style="display:inline;text-align:center"><div id="hosbsxcwemqsofrxyxph_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="hosbsxcwemqsofrxyxph_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default;cursor: pointer;'onmouseover="onMouseHoverFlat_hosbsxcwemqsofrxyxph(this.id)" onmouseout="onMouseOutFlat_hosbsxcwemqsofrxyxph(this.id)" onclick="onMouseClickFlat_hosbsxcwemqsofrxyxph(this.id)" ></div></div><div id="hosbs
# <br/><b>4th instance:</b><br/>
#     <script>
#         function selectVizType_dkmliztnfwbpzvguxfme(selectObject) {
#
#           /* Hide all viz */
#
#             var elements = document.getElementsByClassName("dkmliztnfwbpzvguxfme_viz_container")
#           for (var i = 0; i < elements.length; i++){
#               elements[i].style.display = 'none';
#           }
#
#           var value = selectObject.value;
#           if ( value === "saliency-plot" ){
#               document.getElementById('dkmliztnfwbpzvguxfme_saliency_plot_container').style.display  = "block";
#           }
#           else if ( value === "heatmap" ) {
#               document.getElementById('dkmliztnfwbpzvguxfme_heatmap_container').style.display  = "block";
#           }
#         }
#     </script>
#
#     <html>
#     <div id="dkmliztnfwbpzvguxfme_viz_container">
#       <div id="dkmliztnfwbpzvguxfme_viz_header" style="padding:15px;border-style:solid;margin:5px;font-family:sans-serif;font-weight:bold;">
#         Visualization Type:
#         <select name="viz_type" id="dkmliztnfwbpzvguxfme_viz_type" onchange="selectVizType_dkmliztnfwbpzvguxfme(this)">
#           <option value="heatmap" selected="selected">Input/Output - Heatmap</option>
#           <option value="saliency-plot">Saliency Plot</option>
#         </select>
#       </div>
#       <div id="dkmliztnfwbpzvguxfme_content" style="padding:15px;border-style:solid;margin:5px;">
gba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th><th style="background:rgba(30.0, 136.0, 229.0, 0.5349178055060406)">-2.19</th><th style="background:rgba(30.0, 136.0, 229.0, 0.3220835809071103)">-1.337</th><th style="background:rgba(30.0, 136.0, 229.0, 0.22749059219647463)">-0.953</th><th style="background:rgba(30.0, 136.0, 229.0, 0.14078035254505836)">-0.59</th><th style="background:rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0)">0.0</th></tr></table>
#         </div>
#
#           </div>
#
#           <div id = "dkmliztnfwbpzvguxfme_heatmap_container" class="dkmliztnfwbpzvguxfme_viz_container">
#
#         <div id="tqkxnmiwgxkewbwtbvuf_heatmap" class="tqkxnmiwgxkewbwtbvuf_viz_content">
#           <div id="tqkxnmiwgxkewbwtbvuf_heatmap_header" style="padding:15px;margin:5px;font-family:sans-serif;font-weight:bold;">
#             <div style="display:inline">
#               <span style="font-size: 20px;"> Input/Output - Heatmap </span>
#             </div>
#             <div style="display:inline;float:right">
#               Layout :
#               <select name="alignment" id="tqkxnmiwgxkewbwtbvuf_alignment" onchange="selectAlignment_tqkxnmiwgxkewbwtbvuf(this)">
#                 <option value="left-right" selected="selected">Left/Right</option>
#                 <option value="top-bottom">Top/Bottom</option>
#               </select>
#             </div>
#           </div>
#           <div id="tqkxnmiwgxkewbwtbvuf_heatmap_content" style="display:flex;">
#             <div id="tqkxnmiwgxkewbwtbvuf_input_container" style="padding:15px;border-style:solid;margin:5px;flex:1;">
#               <div id="tqkxnmiwgxkewbwtbvuf_input_header" style="margin:5px;font-weight:bold;font-family:sans-serif;margin-bottom:10px">
#                 Input Text
#               </div>
#               <div id="tqkxnmiwgxkewbwtbvuf_input_content" style="margin:5px;font-family:sans-serif;">
#                   <div id="tqkxnmiwgxkewbwtbvuf_input_node_14_container" style="display:inline;text-align:center"><div id="tqkxnmiwgxkewbwtbvuf_input_node_14_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="tqkxnmiwgxkewbwtbvuf_input_node_14_content" style="display:inline;"><div id="tqkxnmiwgxkewbwtbvuf_input_node_13_container" style="display:inline;text-align:center"><div id="tqkxnmiwgxkewbwtbvuf_input_node_13_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="tqkxnmiwgxkewbwtbvuf_input_node_13_content" style="display:inline;"><div id="tqkxnmiwgxkewbwtbvuf_input_node_0_container" style="display:inline;text-align:center"><div id="tqkxnmiwgxkewbwtbvuf_input_node_0_label" style="display:none; padding-top: 0px; font-size:12px;"></div><div id="tqkxnmiwgxkewbwtbvuf_input_node_0_content"style='display: inline; background:transparent; border-radius: 3px; padding: 0px;cursor: default;cursor: pointer;'onmouseover="onMouseHoverFlat_tqkxnmiwgxkewbwtbvuf(this.id)" onmouseout="onMouseOutFlat_tqkxnmiwgxkewbwtbvuf(this.id)" onclick="onMouseClickFlat_tqkxnmiwgxkewbwtbvuf(this.id)" ></div></div><div id="tqkxnmiwgxkewbwtbvuf_input_node_12_container" style="display:inline;text-align:center"><div id="tqkxnmiwgxkew
