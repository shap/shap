# %% [markdown]
# # GPU TreeExplainer Tests
#
# This notebook runs the GPU TreeExplainer test suite on Google Colab.
#
# **Requirements:** Select a GPU runtime before running:
# - Go to **Runtime > Change runtime type > T4 GPU**

# %% [markdown]
# ## 1. Verify GPU availability

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Clone and install SHAP from source with CUDA support

# %%
# !git clone --depth 1 https://github.com/shap/shap.git -b master /content/shap

# %%
# !cd /content/shap && CUDA_PATH=/usr/local/cuda pip install -e ".[test-core]" -q

# %%
# !pip install xgboost lightgbm -q

# %% [markdown]
# ## 3. Verify that the CUDA extension was built

# %%
from shap.utils import assert_import
assert_import("cext_gpu")
print("CUDA extension loaded successfully")

# %% [markdown]
# ## 4. Run GPU TreeExplainer tests

# %%
# !cd /content/shap && python -m pytest tests/explainers/test_gpu_tree.py -v
