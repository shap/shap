# %% [markdown]
# # GPU TreeExplainer Tests
#
# This notebook runs the GPU TreeExplainer test suite on Google Colab.
#
# **Requirements:** Select a GPU runtime before running:
# - Go to **Runtime > Change runtime type > T4 GPU**

# %% [markdown]
# ## 1. Verify GPU availability

# %%
# !nvidia-smi
# Out:
# Wed Feb 11 21:42:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Clone and install SHAP from source with CUDA support

# %%
# !cd shap && CUDA_PATH=/usr/local/cuda pip install -e ".[test-core]" -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for shap (pyproject.toml) ... done

# %%
# !pip install xgboost lightgbm -q

# %% [markdown]
# ## 3. Run GPU TreeExplainer tests

# %%
# !cd shap && python -m pytest tests/explainers/test_gpu_tree.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# Matplotlib: 3.10.0
# Freetype: 2.6.1
# rootdir: /content/shap
# configfile: pyproject.toml
# plugins: cov-7.0.0, mpl-0.18.0, typeguard-4.4.4, anyio-4.12.1, langsmith-0.6.9
# collected 37 items
#
# tests/explainers/test_gpu_tree.py::test_front_page_xgboost PASSED        [  2%]
# tests/explainers/test_gpu_tree.py::test_xgboost_cat_unsupported PASSED   [  5%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-xgboost.core.Booster] PASSED [  8%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-xgboost.sklearn.XGBRegressor] PASSED [ 10%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-xgboost.sklearn.XGBClassifier0] PASSED [ 13%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-xgboost.sklearn.XGBClassifier1] PASSED [ 16%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-lightgbm.basic.Booster] PASSED [ 18%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-lightgbm.sklearn.LGBMRegressor] PASSED [ 21%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-lightgbm.sklearn.LGBMClassifier0] PASSED [ 24%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-lightgbm.sklearn.LGBMClassifier1] PASSED [ 27%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-sklearn.ensemble._forest.RandomForestClassifier0] PASSED [ 29%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-sklearn.ensemble._forest.RandomForestRegressor] PASSED [ 32%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[interventional-sklearn.ensemble._forest.RandomForestClassifier1] PASSED [ 35%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-xgboost.core.Booster] PASSED [ 37%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-xgboost.sklearn.XGBRegressor] PASSED [ 40%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-xgboost.sklearn.XGBClassifier0] PASSED [ 43%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-xgboost.sklearn.XGBClassifier1] PASSED [ 45%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-lightgbm.basic.Booster] PASSED [ 48%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-lightgbm.sklearn.LGBMRegressor] PASSED [ 51%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-lightgbm.sklearn.LGBMClassifier0] PASSED [ 54%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-lightgbm.sklearn.LGBMClassifier1] PASSED [ 56%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-sklearn.ensemble._forest.RandomForestClassifier0] PASSED [ 59%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-sklearn.ensemble._forest.RandomForestRegressor] PASSED [ 62%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap[tree_path_dependent-sklearn.ensemble._forest.RandomForestClassifier1] PASSED [ 64%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.core.Booster] PASSED [ 67%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.sklearn.XGBRegressor] PASSED [ 70%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.sklearn.XGBClassifier0] PASSED [ 72%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.sklearn.XGBClassifier1] FAILED [ 75%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-lightgbm.basic.Booster] PASSED [ 78%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-lightgbm.sklearn.LGBMRegressor] PASSED [ 81%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-lightgbm.sklearn.LGBMClassifier0] PASSED [ 83%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-lightgbm.sklearn.LGBMClassifier1] PASSED [ 86%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-sklearn.ensemble._forest.RandomForestClassifier0] PASSED [ 89%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-sklearn.ensemble._forest.RandomForestRegressor] PASSED [ 91%]
# tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-sklearn.ensemble._forest.RandomForestClassifier1] PASSED [ 94%]
# tests/explainers/test_gpu_tree.py::test_lightgbm_categorical_split[False] XFAIL [ 97%]
# tests/explainers/test_gpu_tree.py::test_lightgbm_categorical_split[True] XFAIL [100%]
#
# =================================== FAILURES ===================================
# _ test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.sklearn.XGBClassifier1] _
#
# task = (XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=N...+00],
#        [-1.8050423e+00, -2.8020740e+00, -2.7143340e+00, -2.9964082e+00,
#          3.0946665e+00]], dtype=float32))
# feature_perturbation = 'tree_path_dependent'
#
#     @pytest.mark.parametrize("task", tasks, ids=idfn)
#     @pytest.mark.parametrize("feature_perturbation", ["tree_path_dependent"])
#     def test_gpu_tree_explainer_shap_interactions(task, feature_perturbation):
#         model, X, margin = task
#         ex = shap.GPUTreeExplainer(model, X, feature_perturbation=feature_perturbation)
#         shap_values = np.array(ex.shap_interaction_values(X), copy=False)
#
# >       assert np.allclose(np.sum(shap_values, axis=(1, 2)) + ex.expected_value, margin, atol=1e-4)
# E       assert False
# E        +  where False = <function allclose at 0x7ba51adff770>((array([[-8.59039340e-01, -3.53737108e-01, -1.16030345e+00,\n         3.20179458e+00, -1.02802216e+00],\n       [-1.63122985e+00,  3.79527373e+00, -4.99625474e-01,\n        -9.91195813e-03, -1.44334461e+00],\n       [-2.25618880e+00,  4.20067177e+00, -1.40078075e+00,\n        -9.33774216e-01, -4.36777335e-01],\n       [-1.41950289e-01, -1.06370321e-01,  4.20713591e+00,\n        -6.48977472e-01, -1.64706411e+00],\n       [ 3.78214586e+00, -9.63998761e-01,  1.24362450e-01,\n        -8.89569214e-01, -1.11577764e+00],\n       [-2.66723990e+00,  7.50239544e-01, -2.21056781e+00,\n        -1.38802420e+00,  3.49461817e+00],\n       [-1.50225340e+00,  4.69541652e+00, -1.71756531e+00,\n         7.80964289e-02, -5.19511293e-01],\n       [ 3.56255986e+00, -2.11288708e+00, -1.35996873e+00,\n         2.76739016e-01, -2.03302209e+00],\n       [-8.07501869e-01,  1.04637229e+00,  3.49282432e+00,\n        -1.22524793e+00, -1.52245630e+00],\n       [ 8.41272473e-01, -1.64696618e-01,  4.35026410e+00,\n         5.21326398e-01, -2.61084900e+00],\n       [-1.38683748e+00, -5.79382300e-01,  2.65900192e+00,\n        -9.93048966e-01,  3.41199037e-01],\n       [-3.48563351e-01, -2.38177878e+00, -1.12058623e
1.69799894e+00,  3.94592236e+00]]) = <function sum at 0x7ba51adf2ff0>(array([[[[-1.62836641e-01,  6.81088448e-01, -7.70611525e-01,\n          -8.17786902e-02,  1.35339245e-01],\n         [ 9.64628533e-02, -1.60222381e-01, -6.13543577e-02,\n           1.82111859e-01, -3.17990184e-02],\n         [-7.62732178e-02,  9.73348022e-02, -1.83501318e-01,\n           8.48273262e-02,  1.29881585e-02],\n         [ 1.05507746e-01, -3.12932819e-01,  2.02268526e-01,\n           2.51399904e-01, -9.21549872e-02]],\n\n        [[ 9.64628533e-02, -1.60222381e-01, -6.13543652e-02,\n           1.82111859e-01, -3.17990147e-02],\n         [ 6.83241308e-01, -9.48462009e-01, -4.45786655e-01,\n           5.49550533e-01, -1.29938900e+00],\n         [-2.12332830e-04, -2.67938077e-02,  8.96688029e-02,\n           5.20981625e-02, -1.04783185e-01],\n         [-2.14637473e-01,  1.16163671e-01, -4.04046983e-01,\n           4.80072916e-01, -1.51743740e-01]],\n\n        [[-7.62732252e-02,  9.73348022e-02, -1.83501318e-01,\n           8.48273337e-02,  1.29881613e-02],\n         [-2.12331754e-04, -2.67938077e-02,  8.96688104e-02,\n           5.20981587e-02, -1.04783177e-01],\n         [-8.87262970e-02,  9.65642095e-01,  7.72894561e-01,\n          -3.50739807e-01,  2.74376303e-01],\n         [-9.56680626e-02,  ...566e-02,  1.75503656e-01],\n         [ 5.20532057e-02, -9.47887778e-01,  8.06258380e-01,\n          -8.50372851e-01,  1.84633064e+00],\n         [-1.41184069e-02,  6.05594814e-02, -8.61510634e-02,\n          -3.20571214e-02,  3.28021973e-01],\n         [-1.17443435e-01, -1 ...
# E        +      where <function sum at 0x7ba51adf2ff0> = np.sum
# E        +    and   [np.float64(-0.9173383116722107), np.float64(-0.9561627507209778), np.float64(-0.6099249124526978), np.float64(-1.2284101247787476), np.float64(-0.8512561917304993)] = <shap.explainers._gpu_tree.GPUTreeExplainer object at 0x7ba4f0d9fc80>.expected_value
#
# tests/explainers/test_gpu_tree.py:251: AssertionError
# =============================== warnings summary ===============================
# ../../usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739
# ../../usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#     warnings.warn(
#
# ../../usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739
# ../../usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#     warnings.warn(
#
# tests/explainers/test_gpu_tree.py::test_front_page_xgboost
#   /content/shap/tests/explainers/test_gpu_tree.py:42: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#     shap.summary_plot(shap_values, X, show=False)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED tests/explainers/test_gpu_tree.py::test_gpu_tree_explainer_shap_interactions[tree_path_dependent-xgboost.sklearn.XGBClassifier1] - assert False
# ============= 1 failed, 34 passed, 2 xfailed, 5 warnings in 22.67s =============
